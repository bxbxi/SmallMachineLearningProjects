# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/bartu/PycharmProjects/WineQuality/WineQT.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB
# None
# fixed acidity           0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.hist(bins=20, figsize=(20, 15))
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %% [markdown]
# Wine Describe

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.groupby('quality').mean()
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.450000          0.897500     0.211667        2.666667
# 4             7.809091          0.700000     0.165758        2.566667
# 5             8.161077          0.585280     0.240124        2.540476
# 6             8.317749          0.504957     0.263680        2.444805
# 7             8.851049          0.393671     0.386573        2.760140
# 8             8.806250          0.410000     0.432500        2.643750
#
#          chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# quality
# 3         0.105333             8.166667             24.500000  0.997682
# 4         0.094788            14.848485             40.606061  0.996669
# 5         0.091770            16.612836             55.299172  0.997073
# 6         0.085281            15.215368             39.941558  0.996610
# 7         0.075217            14.538462             37.489510  0.996071
# ...

# %%
sns.countplot(df['quality'])
plt.show()

# %%
wine['quality'].unique
# Out:
# <bound method Series.unique of 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1143, dtype: int64>

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
# Load the dataset
file_path = 'WineQT.csv'
df = pd.read_csv(file_path)

# Identify numerical columns
numerical_cols = df.select_dtypes(include=['float64', 'int64']).columns

# Create subplots for each numerical column
fig = make_subplots(rows=len(numerical_cols), cols=1, subplot_titles=numerical_cols)

# Add traces for each numerical column
for i, col in enumerate(numerical_cols, start=1):
    for quality in df['quality'].unique():
        fig.add_trace(go.Histogram(x=df[df['quality'] == quality][col], name=f"{col} (quality {quality})", opacity=0.75), row=i, col=1)

# Update layout
fig.update_layout(height=200*len(numerical_cols), title_text='Numerical Variables Distribution', barmode='overlay')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="c5167296-b7b9-487d-abf1-930e203949f8" class="plotly-graph-div" style="height:2600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5167296-b7b9-487d-abf1-930e203949f8")) {                    Plotly.newPlot(                        "c5167296-b7b9-487d-abf1-930e203949f8",                        [{"name":"fixed acidity (quality 5)","opacity":0.75,"x":[7.4,7.8,7.8,7.4,7.4,7.9,6.7,5.6,7.8,7.6,7.9,8.5,6.3,7.6,7.1,6.7,8.3,5.2,7.3,8.1,7.7,8.8,8.6,10.2,7.8,8.8,7.7,7.0,7.2,7.2,6.6,7.7,8.8,6.7,6.2,7.4,6.9,7.7,9.3,7.0,7.9,7.7,6.8,7.6,8.1,7.2,8.1,7.8,6.2,7.8,8.4,7.8,7.3,7.3,7.8,8.2,8.1,8.0,5.6,8.4,7.2,8.4,6.3,8.1,5.8,7.5,7.5,7.1,7.1,7.1,7.1,7.6,7.4,7.3,7.8,6.8,6.9,7.3,7.0,8.8,8.8,8.9,7.2,6.8,8.9,7.4,7.9,8.2,7.6,7.6,7.3,7.8,8.2,7.0,8.7,8.1,7.5,7.4,6.8,8.9,7.1,11.1,
# ...

# %%
# Ensure 'quality' column exists in the DataFrame
if 'quality' not in df.columns:
    raise KeyError("'quality' column is not present in the DataFrame")

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Display the correlation of 'quality' with other numerical columns
quality_correlation = correlation_matrix['quality'].sort_values(ascending=False)
display(quality_correlation)

# Group by 'quality' and calculate the mean for each numerical column
quality_grouped_means = df.groupby('quality').mean()
display(quality_grouped_means)

# Plot the correlation matrix
fig_corr = px.imshow(correlation_matrix, text_auto=True, title='Correlation Matrix')
fig_corr.show()

# Ensure numerical_cols is defined
numerical_cols = df.select_dtypes(include='number').columns.tolist()
numerical_cols.remove('quality')

# Plot the mean values of numerical columns grouped by 'quality'
fig_grouped_means = make_subplots(rows=len(numerical_cols), cols=1, subplot_titles=numerical_cols)

for i, col in enumerate(numerical_cols, start=1):
    fig_grouped_means.add_trace(go.Bar(x=quality_grouped_means.index, y=quality_grouped_means[col], name=col), row=i, col=1)

fig_grouped_means.update_layout(height=200*len(numerical_cols), title_text='Mean Values of Numerical Columns Grouped by Quality')
fig_grouped_means.show()
# Out:
# quality                 1.000000
# alcohol                 0.484866
# sulphates               0.257710
# citric acid             0.240821
# fixed acidity           0.121970
# Id                      0.069708
# residual sugar          0.022002
# pH                     -0.052453
# free sulfur dioxide    -0.063260
# chlorides              -0.124085
# density                -0.175208
# total sulfur dioxide   -0.183339
# volatile acidity       -0.407394
# Name: quality, dtype: float64
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3             8.450000          0.897500     0.211667        2.666667
# 4             7.809091          0.700000     0.165758        2.566667
# 5             8.161077          0.585280     0.240124        2.540476
# 6             8.317749          0.504957     0.263680        2.444805
# 7             8.851049          0.393671     0.386573        2.760140
# ...

# %%
# Create a scatter plot matrix to visualize the relationships between numerical columns
fig_scatter_matrix = px.scatter_matrix(
    df,
    dimensions=numerical_cols,
    color='quality',
    title='Scatter Matrix of Numerical Columns Colored by Quality'
)

fig_scatter_matrix.update_layout(
    width=1500,
    height=1500,
    dragmode='select',
    hovermode='closest'
)

fig_scatter_matrix.show()
# Out:
# <div>                            <div id="9c21582c-8dcf-4bc3-8d11-b5d0070d7077" class="plotly-graph-div" style="height:1500px; width:1500px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c21582c-8dcf-4bc3-8d11-b5d0070d7077")) {                    Plotly.newPlot(                        "9c21582c-8dcf-4bc3-8d11-b5d0070d7077",                        [{"dimensions":[{"axis":{"matches":true},"label":"fixed acidity","values":[7.4,7.8,7.8,11.2,7.4,7.4,7.9,7.3,7.8,6.7,5.6,7.8,8.5,7.9,7.6,7.9,8.5,6.9,6.3,7.6,7.1,7.8,6.7,8.3,5.2,7.8,7.8,8.1,7.3,8.8,7.5,8.1,4.6,7.7,8.8,6.6,6.6,8.6,7.6,10.2,7.8,7.3,8.8,7.7,7.0,7.2,7.2,6.6,8.0,7.7,8.3,8.8,6.8,6.7,8.3,6.2,7.4,6.3,6.9,8.6,7.7,9.3,7.0,7.9,8.6,7.7,5.0,6.8,7.6,8.1,8.3,8.1,8.1,7.2,8.1,7.8,6.2,7.8,8.4,10.1,7.8,9.4,8.3,7.3,8.8,7.3,7.8,8.2,8.1,8.0,8.0,5.6,7.9,8.4,7.2,8.4,5.2
# ...

# %%
# Rename columns to better recall them.
df.rename(columns = {"fixed acidity": "fixed_acidity",
                       "volatile acidity": "volatile_acidity",
                       "citric acid": "citric_acid",
                       "residual sugar": "residual_sugar",
                       "chlorides": "chlorides",
                       "free sulfur dioxide": "free_sulfur_dioxide",
                       "total sulfur dioxide": "total_sulfur_dioxide"},
            inplace = True)

# %%
columns = list(df.columns)

# %%
fig, ax = plt.subplots(11, 2, figsize=(15, 45))
plt.subplots_adjust(hspace = 0.5)
for i in range(11) :
    # AX 1
    sns.boxplot(x=columns[i], data=df, ax=ax[i, 0])
    # Ax 2
    sns.scatterplot(x=columns[i], y='quality', data=df, hue='quality', ax=ax[i, 1])

# %%
df = df.replace({'quality' : {
                                    8 : 'Good',
                                    7 : 'Good',
                                    6 : 'Middle',
                                    5 : 'Middle',
                                    4 : 'Bad',
                                    3 : 'Bad',
        }}
)

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality  Id
# 0      9.4  Middle   0
# 1      9.8  Middle   1
# ...

# %%
X_temp = df.drop(columns='quality')
y = df.quality

# %%
import warnings
from termcolor import colored

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

# %%
scaler = MinMaxScaler(feature_range=(0, 1)).fit_transform(X_temp)
X = pd.DataFrame(scaler, columns=X_temp.columns)
X.describe().T.style.background_gradient(axis=0, cmap='Purples')
# Out:
# <style type="text/css">
# #T_f5f7f_row0_col0, #T_f5f7f_row0_col3, #T_f5f7f_row1_col0, #T_f5f7f_row1_col3, #T_f5f7f_row1_col7, #T_f5f7f_row2_col0, #T_f5f7f_row2_col3, #T_f5f7f_row3_col0, #T_f5f7f_row3_col1, #T_f5f7f_row3_col3, #T_f5f7f_row3_col5, #T_f5f7f_row3_col6, #T_f5f7f_row4_col0, #T_f5f7f_row4_col2, #T_f5f7f_row4_col3, #T_f5f7f_row4_col7, #T_f5f7f_row5_col0, #T_f5f7f_row5_col3, #T_f5f7f_row6_col0, #T_f5f7f_row6_col3, #T_f5f7f_row6_col4, #T_f5f7f_row6_col7, #T_f5f7f_row7_col0, #T_f5f7f_row7_col3, #T_f5f7f_row8_col0, #T_f5f7f_row8_col3, #T_f5f7f_row9_col0, #T_f5f7f_row9_col3, #T_f5f7f_row10_col0, #T_f5f7f_row10_col3, #T_f5f7f_row11_col0, #T_f5f7f_row11_col3 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_f5f7f_row0_col1 {
#   background-color: #918ec2;
#   color: #f1f1f1;
# }
# #T_f5f7f_row0_col2 {
#   background-color: #c0c1de;
#   color: #000000;
# }
# #T_f5f7f_row0_col4 {
#   background-color: #a3a0cb;
#   color: #f1f1f1;
# }
# #T_f5f7f_row0_col5 {
# ...

# %%
def plot_confusion_matrix(y_test, y_prediction):
    '''Plotting Confusion Matrix'''
    cm = metrics.confusion_matrix(y_test, y_prediction)
    ax = plt.subplot()
    ax = sns.heatmap(cm, annot=True, fmt='', cmap="Purples")
    ax.set_xlabel('Prediced labels', fontsize=18)
    ax.set_ylabel('True labels', fontsize=18)
    ax.set_title('Confusion Matrix', fontsize=25)
    ax.xaxis.set_ticklabels(['Bad', 'Good', 'Middle'])
    ax.yaxis.set_ticklabels(['Bad', 'Good', 'Middle']) 
    plt.show()

# %%
def clfr_plot(y_test, y_pred) :
    cr = pd.DataFrame(metrics.classification_report(y_test, y_pred_rf, digits=3,
                                            output_dict=True)).T
    cr.drop(columns='support', inplace=True)
    sns.heatmap(cr, cmap='Purples', annot=True, linecolor='white', linewidths=0.5).xaxis.tick_top()

# %%
def clf_plot(y_pred) :
    '''
    1) Ploting Confusion Matrix
    2) Plotting Classification Report'''
    cm = metrics.confusion_matrix(y_test, y_pred)
    cr = pd.DataFrame(metrics.classification_report(y_test, y_pred, digits=3, output_dict=True)).T
    cr.drop(columns='support', inplace=True)
    
    fig, ax = plt.subplots(1, 2, figsize=(15, 5))
    
    # Left AX : Confusion Matrix
    ax[0] = sns.heatmap(cm, annot=True, fmt='', cmap="Purples", ax=ax[0])
    ax[0].set_xlabel('Prediced labels', fontsize=18)
    ax[0].set_ylabel('True labels', fontsize=18)
    ax[0].set_title('Confusion Matrix', fontsize=25)
    ax[0].xaxis.set_ticklabels(['Bad', 'Good', 'Middle'])
    ax[0].yaxis.set_ticklabels(['Bad', 'Good', 'Middle'])
    
    # Right AX : Classification Report
    ax[1] = sns.heatmap(cr, cmap='Purples', annot=True, linecolor='white', linewidths=0.5, ax=ax[1])
    ax[1].xaxis.tick_top()
    ax[1].set_title('Classification Report', fontsize=25)
    plt.show()

# %%
df.quality.value_counts()
# Out:
# quality
# Middle    945
# Good      159
# Bad        39
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
parameters = {
    'n_estimators' : [50, 150, 500],
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'max_features' : ['sqrt', 'log2']
}

rf = RandomForestClassifier(n_jobs=-1)
rf_cv = GridSearchCV(estimator=rf, cv=20, param_grid=parameters).fit(X_train, y_train)

print('Tuned hyper parameters : ', rf_cv.best_params_)
print('accuracy : ', rf_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'criterion': 'gini', 'max_features': 'log2', 'n_estimators': 500}
# accuracy :  0.8774640088593577

# %%
rf = RandomForestClassifier(**rf_cv.best_params_).fit(X_train, y_train)

# %%
y_pred_rf = rf.predict(X_test)

rf_score = round(rf.score(X_test, y_test), 3)
print('RandomForestClassifier score : ', rf_score)
# Out:
# RandomForestClassifier score :  0.881

# %%
y_test.value_counts()
# Out:
# quality
# Middle    242
# Good       36
# Bad         8
# Name: count, dtype: int64

# %%
clf_plot(y_pred_rf)
# Out:
# C:\Users\bartu\PycharmProjects\WineQuality\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\bartu\PycharmProjects\WineQuality\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\bartu\PycharmProjects\WineQuality\venv\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning:
#
# Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %%
from lazypredict.Supervised import LazyClassifier

# %%
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
print(models)
# Out:
# 100%|██████████| 31/31 [00:01<00:00, 28.67it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000100 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1185
# [LightGBM] [Info] Number of data points in the train set: 857, number of used features: 12
# [LightGBM] [Info] Start training from score -3.319451
# [LightGBM] [Info] Start training from score -1.941254
# [LightGBM] [Info] Start training from score -0.198081
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# NearestCentroid                    0.52               0.61    None      0.60
# GaussianNB                         0.82               0.59    None      0.83
# ...
